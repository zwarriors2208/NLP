# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping

# %%
# sample data = english t french translation
english_sentences = ['hello', 'how are you', 'good morning', 'good night', 'thank you']
french_sentences = ['bonjour', 'comment ca va', 'bonjour', 'bonne nuit', 'merci']

# %%
# Add START and END tokens to the French (output) sentences
french_sentences = ['starttoken '+ sentence+' endtoken' for sentence in french_sentences]

# Hyperparameters
batch_size =2
epochs= 100
latent_dim = 256 # Dimensionality of the encoding space

# %%
french_sentences
# Out:
# ['starttoken bonjour endtoken',
#  'starttoken comment ca va endtoken',
#  'starttoken bonjour endtoken',
#  'starttoken bonne nuit endtoken',
#  'starttoken merci endtoken']

# %%
# Initialize the Tokenizer for both source and target languages
eng_tokenizer = Tokenizer(char_level = False)
fra_tokenizer = Tokenizer(char_level = False)

# Fit the Tokenizer on the sentences
eng_tokenizer.fit_on_texts(english_sentences)
fra_tokenizer.fit_on_texts(french_sentences)

# %%
display(eng_tokenizer.word_index)
display(fra_tokenizer.word_index)
# Out:
# {'you': 1,
#  'good': 2,
#  'hello': 3,
#  'how': 4,
#  'are': 5,
#  'morning': 6,
#  'night': 7,
#  'thank': 8}
# {'starttoken': 1,
#  'endtoken': 2,
#  'bonjour': 3,
#  'comment': 4,
#  'ca': 5,
#  'va': 6,
#  'bonne': 7,
#  'nuit': 8,
#  'merci': 9}

# %%
# convert the sentences into sequences of integes
encoder_input_data = eng_tokenizer.texts_to_sequences(english_sentences)
decoder_input_data = fra_tokenizer.texts_to_sequences(french_sentences)

# %%
# Pad the sequences to ensure uniform length
max_encoder_seq_length = max([len(seq) for seq in encoder_input_data])
max_decoder_seq_length = max([len(seq) for seq in decoder_input_data])

# %%
max_encoder_seq_length,  max_decoder_seq_length
# Out:
# (3, 5)

# %%
encoder_input_data= pad_sequences(encoder_input_data, maxlen=max_encoder_seq_length, padding = 'post')
decoder_input_data= pad_sequences(decoder_input_data, maxlen=max_decoder_seq_length, padding = 'post')

# %%
encoder_input_data
# Out:
# array([[3, 0, 0],
#        [4, 5, 1],
#        [2, 6, 0],
#        [2, 7, 0],
#        [8, 1, 0]], dtype=int32)

# %%
decoder_input_data
# Out:
# array([[1, 3, 2, 0, 0],
#        [1, 4, 5, 6, 2],
#        [1, 3, 2, 0, 0],
#        [1, 7, 8, 2, 0],
#        [1, 9, 2, 0, 0]], dtype=int32)

# %%
# Prepare the target data (decoder output, shifted by one time step)
decoder_output_data = np.zeros_like(decoder_input_data)
decoder_output_data[:,0:-1] = decoder_input_data[:,1:]

# %%
decoder_output_data
# Out:
# array([[3, 2, 0, 0, 0],
#        [4, 5, 6, 2, 0],
#        [3, 2, 0, 0, 0],
#        [7, 8, 2, 0, 0],
#        [9, 2, 0, 0, 0]], dtype=int32)

# %%
decoder_input_data # time step differnce between the output data and input data
# Out:
# array([[1, 3, 2, 0, 0],
#        [1, 4, 5, 6, 2],
#        [1, 3, 2, 0, 0],
#        [1, 7, 8, 2, 0],
#        [1, 9, 2, 0, 0]], dtype=int32)

# %%
# Define the vocabulary size (total unique tokens)
num_encoder_tokens = len(eng_tokenizer.word_index) + 1
num_decoder_tokens = len(fra_tokenizer.word_index) + 1

# %%
num_encoder_tokens, num_decoder_tokens
# Out:
# (9, 10)

# %%
# Define the input sequence and output sequence for the Seq2Seq mode
encoder_inputs = Input(shape=(None,))
decoder_inputs = Input(shape=(None,))

# %%
encoder_inputs
# Out:
# <KerasTensor shape=(None, None), dtype=float32, sparse=False, name=keras_tensor_28>

# %%
# Encoder
encoder_embedding = Embedding(input_dim = num_encoder_tokens, output_dim = latent_dim, input_length = max_encoder_seq_length)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm (encoder_embedding)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
encoder_outputs
# Out:
# <KerasTensor shape=(None, 256), dtype=float32, sparse=False, name=keras_tensor_31>

# %%
state_h
# Out:
# <KerasTensor shape=(None, 256), dtype=float32, sparse=False, name=keras_tensor_32>

# %%
state_c
# Out:
# <KerasTensor shape=(None, 256), dtype=float32, sparse=False, name=keras_tensor_33>

# %%
decoder_embedding = Embedding(input_dim = num_decoder_tokens, output_dim = latent_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim,return_sequences= True, return_state=True)
decoder_outputs, _, _ = decoder_lstm (decoder_embedding, initial_state= [state_h, state_c])

# %%
# Dense layer for generating predictions
decoder_dense= Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model
model = Model ([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3             │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_4             │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_6 (Embedding)   │ (None, None, 256)      │          2,304 │ input_layer_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_7 (Embedding)   │ (None, None, 256)      │          2,560 │ input_layer_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_6 (LSTM)             │ [(None, 256), (None,   │        525,312 │ embedding_6[0][0]      │
# │                           │ 256), (None, 256)]     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_7 (LSTM)             │ [(None, None, 256),    │        525,312 │ embedding_7[0][0],     │
# │                           │ (None, 256), (None,    │                │ lstm_6[0][1],          │
# │                           │ 256)]                  │                │ lstm_6[0][2]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, None, 10)       │          2,570 │ lstm_7[0][0]           │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,058,058 (4.04 MB)
#  Trainable params: 1,058,058 (4.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model.compile( optimizer ='adam',
              loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

# %%
# Train the model
model.fit([encoder_input_data, decoder_input_data], np.expand_dims(decoder_output_data, -1),
          batch_size=batch_size,
          epochs=epochs)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.2225 - loss: 2.2816
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4525 - loss: 2.1479
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5025 - loss: 1.9051
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5275 - loss: 1.4421
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4775 - loss: 1.2824
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4525 - loss: 1.3194
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5025 - loss: 1.0423
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7275 - loss: 0.8970
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6525 - loss: 1.0451
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7025 - loss: 0.8283
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6525 - loss: 0.8774
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7100 - loss: 0.8088
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7625 - loss: 0.8542
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8275 - loss: 0.6460
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8325 - loss: 0.5983
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8325 - loss: 0.5045
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8625 - loss: 0.3933
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9150 - loss: 0.4119
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6925 - loss: 0.7309
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8075 - loss: 0.4297
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8275 - loss: 0.3985
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9350 - loss: 0.3055
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9150 - loss: 0.2693
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9100 - loss: 0.3073
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9675 - loss: 0.2175
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9425 - loss: 0.2299
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9800 - loss: 0.2090
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9800 - loss: 0.1244
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.1435
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.1437
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0880
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0714
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.1034
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0987
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0648
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0674
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0333
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0563
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0392
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0451
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0250
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0186
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0317
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0227
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0298
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0193
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0232
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0203
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0199
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0098
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0160
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0014

# %%
# Create infernece models for the encoder and decocder for predictions
#Encoder model
encoder_model = Model(encoder_inputs, [encoder_outputs, state_h, state_c])

# %%
# Decoder model (for inference)
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_lstm_inf =LSTM (latent_dim, return_sequences= True, return_state=True)
decoder_output_inf, state_h_inf, state_c_inf = decoder_lstm_inf(
    decoder_embedding, initial_state=[decoder_state_input_h, decoder_state_input_c])
decoder_output_inf = decoder_dense(decoder_output_inf)
decoder_model = Model([decoder_inputs, decoder_state_input_h,
                       decoder_state_input_c],
                      [decoder_output_inf, state_h_inf, state_c_inf])

# %%
# Function to decode the sequence
def decode_sequence(input_seq):
  # Get the encoder states
  states_value = encoder_model.predict(input_seq)
  # Generate an initial target sequence (the start token)
  target_seq = np.zeros((1, 1))
  target_seq[0, 0] = fra_tokenizer.word_index['starttoken'] # start token index

  # Sample output tokens
  stop_condition = False
  decoded_sentence = ''
  while not stop_condition:
    # Correct the prediction input to match expected inputs
    output_tokens, h, c = decoder_model.predict([target_seq, states_value[1], states_value[2]])

    # Sample the next token
    sampled_token_index = np.argmax(output_tokens[0,
                                                  -1,:])
    sampled_token = fra_tokenizer.index_word[sampled_token_index]

    decoded_sentence += ' ' + sampled_token

    # Stop if we hit the end token or reach max length
    if sampled_token == 'endtoken' or len(decoded_sentence) > max_decoder_seq_length:
      stop_condition = True

    # Update the target sequence and states
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = sampled_token_index

    #update the states
    states_value = [h, c]

  return decoded_sentence

# %%
# test the decoder with a simple sentence
input_seq = encoder_input_data[2:3] # sample input sentance

# %%
input_seq
# Out:
# array([[2, 6, 0]], dtype=int32)

# %%
encoder_input_data
# Out:
# array([[3, 0, 0],
#        [4, 5, 1],
#        [2, 6, 0],
#        [2, 7, 0],
#        [8, 1, 0]], dtype=int32)

# %%
decoded_sentence = decode_sequence(input_seq)
print(decoded_sentence)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#  bonjour

# %%
new = 'good night'

# %%
input_seq = encoder_input_data[3:4]

# %%
decoded_sentence = decode_sequence(input_seq)
print(decoded_sentence)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#  bonne
