# %%
from polyglot.downloader import downloader

downloader.download("morph2.en")
downloader.download("morph2.mr")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-494be7641fb6> in <cell line: 1>()
# ----> 1 from polyglot.downloader import downloader
#       2
#       3 downloader.download("morph2.en")
#       4 downloader.download("morph2.mr")
#
# ModuleNotFoundError: No module named 'polyglot'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install morfessor polyglot
# Out:
# Collecting morfessor
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Collecting polyglot
#   Downloading polyglot-16.7.4.tar.gz (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.3/126.3 kB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Building wheels for collected packages: polyglot
#   Building wheel for polyglot (setup.py) ... done
#   Created wheel for polyglot: filename=polyglot-16.7.4-py2.py3-none-any.whl size=52562 sha256=de002ec43acddce6a3ab758e8cc1b6dc49ba7e482825a689c6cf6e60a5ffc39f
#   Stored in directory: /root/.cache/pip/wheels/aa/92/4a/b172589446ba537db3bdb9a1f2204f27fe71217981c14ac368
# Successfully built polyglot
# Installing collected packages: polyglot, morfessor
# Successfully installed morfessor-2.0.6 polyglot-16.7.4

# %%
pip install PyICU
# Out:
# Collecting PyICU
#   Downloading PyICU-2.14.tar.gz (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.9/263.9 kB 15.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: PyICU
#   Building wheel for PyICU (pyproject.toml) ... done
#   Created wheel for PyICU: filename=PyICU-2.14-cp310-cp310-linux_x86_64.whl size=1809838 sha256=93ece13ac0a3c41b54b9de5afbba28be24064cfefbbacb371172d66824627238
#   Stored in directory: /root/.cache/pip/wheels/78/6e/76/17c73021179c06c29d9b108896b9248da0de4f2af93f63d405
# Successfully built PyICU
# Installing collected packages: PyICU
# Successfully installed PyICU-2.14

# %%
pip install pycld2
# Out:
# Collecting pycld2
#   Downloading pycld2-0.41.tar.gz (41.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 35.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pycld2
#   Building wheel for pycld2 (setup.py) ... done
#   Created wheel for pycld2: filename=pycld2-0.41-cp310-cp310-linux_x86_64.whl size=9904039 sha256=da32e0fe7deacbab957b8d5446977d4ac1ec5a1c6140afe43ec4dd74c498aeeb
#   Stored in directory: /root/.cache/pip/wheels/be/81/31/240c89c845e008a93d98542325270007de595bfd356eb0b06c
# Successfully built pycld2
# Installing collected packages: pycld2
# Successfully installed pycld2-0.41

# %%
from polyglot.downloader import downloader

downloader.download("morph2.en")
# Out:
# [polyglot_data] Downloading package morph2.en to
# [polyglot_data]     /root/polyglot_data...
# [polyglot_data] Error downloading 'morph2.en' from <http://polyglot.cs
# [polyglot_data]     .stonybrook.edu/~polyglot/morph2/en/en.morph.tar.b
# [polyglot_data]     z2>:   <urlopen error [Errno 110] Connection timed
# [polyglot_data]     out>
# False

# %%
from polyglot.downloader import downloader

downloader.download("morph2.en")
downloader.download("morph2.mr")
# Out:
# [polyglot_data] Error loading morph2.en: <urlopen error [Errno 110]
# [polyglot_data]     Connection timed out>
# [polyglot_data] Downloading package morph2.mr to
# [polyglot_data]     /root/polyglot_data...
# True

# %%
from polyglot.text import Text, Word

# %%
words = ['cats', 'computing', 'association', 'programming', 'leadership', 'miscommunication', 'identifiable'
,'psychologically', 'engineering', 'tabular', 'realistic', 'colorfulness']
for w in words:
  w = Word(w, language="en")
  print(w , '\t\t',  w.morphemes)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-4f33790cea73> in <cell line: 3>()
#       3 for w in words:
#       4   w = Word(w, language="en")
# ----> 5   print(w , '\t\t',  w.morphemes)
#
# /usr/local/lib/python3.10/dist-packages/polyglot/decorators.py in __get__(self, obj, cls)
#      18     if obj is None:
#      19         return self
# ---> 20     value = obj.__dict__[self.func.__name__] = self.func(obj)
#      21     return value
#      22
#
# /usr/local/lib/python3.10/dist-packages/polyglot/text.py in morphemes(self)
#     284   @cached_property
#     285   def morphemes(self):
# --> 286     words, score = self.morpheme_analyzer.viterbi_segment(self.string)
#     287     return WordList(words, parent=self, language=self.language)
#     288
#
# /usr/local/lib/python3.10/dist-packages/polyglot/decorators.py in __get__(self, obj, cls)
#      18     if obj is None:
#      19         return self
# ---> 20     value = obj.__dict__[self.func.__name__] = self.func(obj)
#      21     return value
#      22
#
# /usr/local/lib/python3.10/dist-packages/polyglot/text.py in morpheme_analyzer(self)
#     280   @cached_property
#     281   def morpheme_analyzer(self):
# --> 282     return load_morfessor_model(lang=self.language)
#     283
#     284   @cached_property
#
# /usr/local/lib/python3.10/dist-packages/polyglot/decorators.py in memoizer(*args, **kwargs)
#      28     key = tuple(list(args) + sorted(kwargs.items()))
#      29     if key not in cache:
# ---> 30       cache[key] = obj(*args, **kwargs)
#      31     return cache[key]
#      32   return memoizer
#
# /usr/local/lib/python3.10/dist-packages/polyglot/load.py in load_morfessor_model(lang, version)
#     134   """
#     135   src_dir = "morph{}".format(version)
# --> 136   p = locate_resource(src_dir, lang)
#     137   file_handler = _open(p)
#     138   tmp_file_ = NamedTemporaryFile(delete=False)
#
# /usr/local/lib/python3.10/dist-packages/polyglot/load.py in locate_resource(name, lang, filter)
#      45                        "but not downloaded, yet. Try to run\n\n"
#      46                        "polyglot download {}".format(package_id))
# ---> 47   return path.join(p, os.listdir(p)[0])
#      48
#      49
#
# IndexError: list index out of range

# %%
words = ['प्रमाणीकरण', 'जलविद्युत', 'राज्यशास्त्र', 'जलप्राधिकरण', 'मानसशास्त्रीय', 'रविवार', 'महाद्वीप' ]
for w in words:
  w = Word(w, language="mr")
  print(w , '\t\t',  w.morphemes)
# Out:
# प्रमाणीकरण 		 ['प्रमाण', 'ीकरण']
# जलविद्युत 		 ['जल', 'विद्युत']
# राज्यशास्त्र 		 ['राज्य', 'शास्त्र']
# जलप्राधिकरण 		 ['जल', 'प्राधिकरण']
# मानसशास्त्रीय 		 ['मानस', 'शास्त्र', 'ीय']
# रविवार 		 ['रवि', 'वार']
# महाद्वीप 		 ['महा', 'द्वीप']
